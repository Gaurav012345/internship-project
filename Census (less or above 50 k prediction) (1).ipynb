# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Gaurav Kumar\Desktop\DATA TRAINED\Internship Project\census_income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Here the Age is between 17 to 90 yrs
#
# Education has a range between 1 to 16
#
# Capital Gain has some outliers as min 75% data is 0 and similarly capitl loss has 75% of data is  0.
#
# Hours range between 1 to 99

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,10))
plt.title('Income',fontsize=20)
sns.countplot(y='Income',data=df)
plt.show()
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
#  The Dataset is imbalanced

# %%
plt.figure(figsize=(10,10))
plt.title('Workclass',fontsize=20)
sns.countplot(y='Workclass',data=df)
plt.show()
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# Here we see that we have non mentioned workclass force 1836 Qty. Majority of the workclass force is in Private

# %%
plt.figure(figsize=(10,10))
plt.title('Education',fontsize=20)
sns.countplot(y='Education',data=df)
plt.show()
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %% [markdown]
# There are 16 Education categories and from HS - Grad the workforce no. is highest

# %%
plt.figure(figsize=(10,10))
plt.title('Marital_status',fontsize=20)
sns.countplot(x='Marital_status',data=df)
plt.show()
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %% [markdown]
# There are 7 categories available in this category with maximum no. of workforce is in married-civ-spouse

# %%
plt.figure(figsize=(20,10))
plt.title('Occupation',fontsize=20)
sns.countplot(x='Occupation',data=df)
plt.show()
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %% [markdown]
# There are 14 categories available in the Occupation at highest ccupation being proof specialty. Also 1843 unknown workforce

# %%
plt.figure(figsize=(10,10))
plt.title('Relationship',fontsize=20)
sns.countplot(x='Relationship',data=df)
plt.show()
df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %% [markdown]
# There are 6 categories an maximum workforce are Husband.

# %%
plt.figure(figsize=(10,10))
plt.title('Race',fontsize=20)
sns.countplot(x='Race',data=df)
plt.show()
df['Race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %% [markdown]
# Maximum no. of workforce is of white category

# %%
plt.figure(figsize=(10,10))
plt.title('Sex',fontsize=20)
sns.countplot(x='Sex',data=df)
plt.show()
df['Sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %% [markdown]
# We have high nos of male than female workforcce

# %%
plt.figure(figsize=(30,10))
plt.title('Native_country',fontsize=20)
sns.countplot(x='Native_country',data=df)
plt.show()
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %% [markdown]
# we have 583 people where country is missing category name.

# %%
plt.figure(figsize=(10,10))
plt.title('Age',fontsize=20)
sns.distplot(df['Age'])
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is right skewed, Maximum no. of workfoce is between range from Age 20 to 50

# %%
plt.figure(figsize=(10,10))
plt.title('Capital_gain',fontsize=20)
sns.distplot(df['Capital_gain'])
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Major Value is set to 0 and data is right skewed

# %%
plt.figure(figsize=(10,10))
plt.title('Capital_loss',fontsize=20)
sns.distplot(df['Capital_loss'])
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# It has 0 values in majority and right skewed

# %%
# Creating a countplot of income across age
plt.figure(figsize=(20, 7))
sns.countplot(df['Age'], hue=df['Income'])
plt.title('Income Dist. Across Age',fontsize= 20)
plt.xlabel('Age',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Almost every age from 17 to 90 one or more is  having a salary above 50K

# %%
# Creating a countplot of income across Education
plt.figure(figsize=(20, 7))
sns.countplot(df['Education'], hue=df['Income'])
plt.title('Income Dist. Across Education',fontsize= 20)
plt.xlabel('Education',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# A large amount of people in Bachelors ,HS grad and Some college people have high salary above 50k, While Hs grad and some college people have High salary But from that same group few people have Less thn 50 K salary.

# %%
# Creating a countplot of income across Education yrs
plt.figure(figsize=(20, 7))
sns.countplot(df['Education_num'], hue=df['Income'])
plt.title('Income Dist. Across No.of yrs in education',fontsize= 20)
plt.xlabel('Education_num',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# People having 9 to 10 yrs of exp has large no. of people has salary above 50K

# %%
# Creating a countplot of income across Marital Status
plt.figure(figsize=(20, 7))
sns.countplot(df['Marital_status'], hue=df['Income'])
plt.title('Income Dist. Across MS',fontsize= 20)
plt.xlabel('Marital_staus',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The Unmarried people are more in nos have salary above 50K

# %%
# Creating a countplot of income across Relationship
plt.figure(figsize=(20, 7))
sns.countplot(df['Relationship'], hue=df['Income'])
plt.title('Income Dist. Across Relationship',fontsize= 20)
plt.xlabel('Relationship',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Husband and Not in family people have higer in nos whose salary is above 50K

# %%
# Creating a countplot of income across Sex
plt.figure(figsize=(20, 7))
sns.countplot(df['Sex'], hue=df['Income'])
plt.title('Income Dist. Across MS',fontsize= 20)
plt.xlabel('Sex',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Male population i higher tha female population ,salary having above 50K

# %%
# Creating a countplot of income across Hours per week
plt.figure(figsize=(20, 7))
sns.countplot(df['Hours_per_week'], hue=df['Income'])
plt.title('Income Dist. Across no. of Hours working',fontsize= 20)
plt.xlabel('Hours_per_week',fontsize=20 )
plt.ylabel('Number of people', fontsize=20)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# people working 40 hrs a week are hihest in nos wose salary is above 50K

# %%
#Heatmap
correlation=df.corr()
sns.heatmap(correlation, fmt='.1f',annot=True, annot_kws={'size':20})
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Income'] = le.fit_transform(df['Income'])

# %% [markdown]
# # DATA PREPROCESSING

# %%
df = df.replace('?', np.nan)

# %%
# Checking null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
for col in df:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
# encoding of dataset
for col in df.columns:
    if df[col].dtypes == 'object':
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  int32
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  int32
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  int32
#  6   Occupation      32560 non-null  int32
#  7   Relationship    32560 non-null  int32
#  8   Race            32560 non-null  int32
#  9   Sex             32560 non-null  int32
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  int32
#  14  Income          32560 non-null  int32
# dtypes: int32(9), int64(6)
# memory usage: 2.6 MB

# %% [markdown]
# # Resampling

# %%
# To balance the dataset we are going for oversampling as we do not want to lose data by undersampling
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
ros.fit(X, y)
# Out:
# RandomOverSampler(random_state=42)

# %%
X_ros, y_ros = ros.fit_resample(X, y)

# %%
y_ros.value_counts()
# Out:
# 0    24719
# 1    24719
# Name: Income, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X=df.drop('Income',axis=1)
y=df['Income']

# %%
df=sc.fit_transform(X)

# %% [markdown]
# # Splitting of data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_ros, y_ros, test_size=0.3, random_state=22)

# %% [markdown]
# # Data Modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# # Logitic Regression

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_ypred = lr.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, lr_ypred))
print(classification_report(y_test, lr_ypred))
# Out:
# Accuracy:  0.6552049622437972
#               precision    recall  f1-score   support
#
#            0       0.64      0.74      0.68      7447
#            1       0.68      0.57      0.62      7385
#
#     accuracy                           0.66     14832
#    macro avg       0.66      0.65      0.65     14832
# weighted avg       0.66      0.66      0.65     14832

# %% [markdown]
# # KNeighbors Classifier

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
knn_ypred=knn.predict(X_test)

# %%
 print("Accuracy: ", accuracy_score(y_test, knn_ypred))
print(classification_report(y_test, knn_ypred))
# Out:
# Accuracy:  0.7192556634304207
#               precision    recall  f1-score   support
#
#            0       0.77      0.63      0.69      7447
#            1       0.68      0.81      0.74      7385
#
#     accuracy                           0.72     14832
#    macro avg       0.73      0.72      0.72     14832
# weighted avg       0.73      0.72      0.72     14832

# %% [markdown]
# # SVC

# %%
svc=SVC()
svc.fit(X_train,y_train)
svc_ypred=svc.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, svc_ypred))
print(classification_report(y_test, svc_ypred))
# Out:
# Accuracy:  0.5927723840345199
#               precision    recall  f1-score   support
#
#            0       0.55      0.99      0.71      7447
#            1       0.94      0.19      0.32      7385
#
#     accuracy                           0.59     14832
#    macro avg       0.75      0.59      0.52     14832
# weighted avg       0.75      0.59      0.52     14832

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
rfc_ypred=rfc.predict(X_test)

# %%
print("Accuracy: ", accuracy_score(y_test, rfc_ypred))
print(classification_report(y_test, rfc_ypred))
# Out:
# Accuracy:  0.9251618122977346
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92      7447
#            1       0.89      0.97      0.93      7385
#
#     accuracy                           0.93     14832
#    macro avg       0.93      0.93      0.93     14832
# weighted avg       0.93      0.93      0.93     14832

# %%
# We get the best result through Random forest classifier which is 92%

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(3,8):
    cv=cross_val_score(rfc,X,y,cv=i)
    print(rfc,cv.mean())
# Out:
# RandomForestClassifier() 0.8571561401200637
# RandomForestClassifier() 0.8571253071253072
# RandomForestClassifier() 0.8576167076167076
# RandomForestClassifier() 0.856787651210304
# RandomForestClassifier() 0.857555626165378

# %%
# we see that the model will perform well with new to about 85%.

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'max_depth':[3,4,5],'n_estimators':[5,5,100]}

# %%
rfc_tuned = RandomForestClassifier()

# %%
gv=GridSearchCV(rfc_tuned,params)
ht=gv.fit(X_train,y_train)

# %%
ht.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 100}

# %%
rf_best = RandomForestClassifier(max_depth=5, n_estimators=100)

# %%
rf_best.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
rf_best_ypred = rf_best.predict(X_test)

# %%
print('Random Forest Classifier:')
print('Accuracy score:', accuracy_score(y_test, rf_best_ypred))
# Out:
# Random Forest Classifier:
# Accuracy score: 0.8127022653721683

# %% [markdown]
# By hypertuning the best prdiction score reaches to 82% which is not bad for a model

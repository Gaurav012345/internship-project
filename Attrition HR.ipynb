# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\Gaurav Kumar\Desktop\DATA TRAINED\Internship Project\dataset\IBM_HR_Attrition_Rate_Analytics-master\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# no null values

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# there are no missing values and 26 columns are numerical while other 9 columns are categorical

# %% [markdown]
# # Categorical Columns

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,10))
plt.title('Attrition numbers',fontsize=20)
sns.countplot(y='Attrition',data=df)
plt.show()
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Data is imbalanced

# %%
# Department wise Attrition
plt.figure(figsize=(15,8))
plt.title('Department wise Attrition numbers',fontsize=20)
sns.countplot(x='Department',hue='Attrition',data=df)
plt.show()
df[['Department','Attrition']].value_counts()
# Out:
# Department              Attrition
# Research & Development  No           828
# Sales                   No           354
# Research & Development  Yes          133
# Sales                   Yes           92
# Human Resources         No            51
#                         Yes           12
# dtype: int64

# %% [markdown]
# Here relatively Attrition percentage is higher in sales than human resource and then research and development

# %%
# Job role wise Attrition
plt.figure(figsize=(20,15))
plt.title('Department wise Attrition numbers',fontsize=20)
sns.countplot(x='JobRole',hue='Attrition',data=df)
plt.show()
df[['JobRole','Attrition']].value_counts()
# Out:
# JobRole                    Attrition
# Sales Executive            No           269
# Research Scientist         No           245
# Laboratory Technician      No           197
# Manufacturing Director     No           135
# Healthcare Representative  No           122
# Manager                    No            97
# Research Director          No            78
# Laboratory Technician      Yes           62
# Sales Executive            Yes           57
# Sales Representative       No            50
# Research Scientist         Yes           47
# Human Resources            No            40
# Sales Representative       Yes           33
# Human Resources            Yes           12
# Manufacturing Director     Yes           10
# Healthcare Representative  Yes            9
# Manager                    Yes            5
# Research Director          Yes            2
# dtype: int64

# %% [markdown]
# Sales representative Attrition rate is higher relatively.

# %%
ord_feat=['Education','EnvironmentSatisfaction','JobSatisfaction','JobInvolvement',
          'PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']
df[ord_feat]
# Out:
#       Education  EnvironmentSatisfaction  JobSatisfaction  JobInvolvement  \
# 0             2                        2                4               3
# 1             1                        3                2               2
# 2             2                        4                3               2
# 3             4                        4                3               3
# 4             1                        1                2               3
# ...         ...                      ...              ...             ...
# 1465          2                        3                4               4
# 1466          1                        4                1               2
# 1467          3                        2                2               4
# 1468          3                        4                2               2
# 1469          3                        2                3               4
#
#       PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# ...

# %%
#education wise attrition
plt.figure(figsize=(20,15))
plt.title('Education wise Attrition numbers',fontsize=20)
sns.countplot(x='Education',hue='Attrition',data=df)
plt.show()
df[['Education','Attrition']].value_counts()
# Out:
# Education  Attrition
# 3          No           473
# 4          No           340
# 2          No           238
# 1          No           139
# 3          Yes           99
# 4          Yes           58
# 2          Yes           44
# 5          No            43
# 1          Yes           31
# 5          Yes            5
# dtype: int64

# %% [markdown]
# Let see if 1 is below college,2 is college ,3 is bachelors , 4 is masters and 5 is doctorate then we can analyze that 1 which is below college is relatively higher attrition percentage whereas bachelors which is 3 has higher attrition numbers.

# %% [markdown]
# # Label Encoding

# %%
# encode categorical columns
from sklearn.preprocessing import LabelEncoder

# %%
le_col=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
Label_Encoders={}
for column in le_col:
    Label_Encoders[column]=LabelEncoder()
    df[column]=Label_Encoders[column].fit_transform(df[column])

# %%
# Attrition Encoding
df['Attrition']=df['Attrition'].replace({'No':0,'Yes':1})
#Encode Binary variables
df['OverTime']=df['OverTime'].replace({'No':0,'Yes':1})
df['Gender']=df['Gender'].replace({'Male':0,'Female':1})
df['Over18']=df['Over18'].replace({'Y':0,'No':1})

# %%
df[['Gender','OverTime','Over18']]
# Out:
#       Gender  OverTime  Over18
# 0          1         1       0
# 1          0         0       0
# 2          0         1       0
# 3          1         1       0
# 4          0         0       0
# ...      ...       ...     ...
# 1465       0         0       0
# 1466       0         0       0
# 1467       0         1       0
# 1468       0         0       0
# 1469       0         0       0
#
# [1470 rows x 3 columns]

# %% [markdown]
# # Correlation

# %%
corr = df.corr()
plt.figure(figsize=(60,40))
sns.heatmap(corr, cbar=True, fmt='.2f', annot=True, annot_kws={'size':15})
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train & Test(Splitting of data)

# %%
X=df.drop(['Attrition'],axis=1)
y=df['Attrition']

# %% [markdown]
# # Resampling

# %%
# To balance the dataset we are going for oversampling as we do not want to lose data by undersampling
# !pip install imbalanced-learn
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
Rs=RandomOverSampler(random_state=32)
X_over,y_over=Rs.fit_resample(X,y)
print(Counter(y_over))
# Out:
# ...
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_over, y_over, test_size =0.2,random_state=32)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
#Random Foret classification
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
rfc_predictions = rfc.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, rfc_predictions))
# Out:
# Accuracy:  0.9615384615384616

# %%
print(classification_report(y_test, rfc_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       241
#            1       0.95      0.97      0.96       253
#
#     accuracy                           0.96       494
#    macro avg       0.96      0.96      0.96       494
# weighted avg       0.96      0.96      0.96       494

# %%
# Logistics Regression
lr = LogisticRegression()
lr.fit(X_train,y_train)
lr_predictions = lr.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, lr_predictions))
print(classification_report(y_test, lr_predictions))
# Out:
# Accuracy:  0.631578947368421
#               precision    recall  f1-score   support
#
#            0       0.62      0.63      0.63       241
#            1       0.64      0.63      0.64       253
#
#     accuracy                           0.63       494
#    macro avg       0.63      0.63      0.63       494
# weighted avg       0.63      0.63      0.63       494
# C:\Users\Gaurav Kumar\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# KNN
kn = KNeighborsClassifier()
kn.fit(X_train,y_train)
kn_predictions = kn.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, kn_predictions))
print(classification_report(y_test, kn_predictions))
# Out:
# Accuracy:  0.742914979757085
#               precision    recall  f1-score   support
#
#            0       0.81      0.62      0.70       241
#            1       0.70      0.86      0.77       253
#
#     accuracy                           0.74       494
#    macro avg       0.76      0.74      0.74       494
# weighted avg       0.76      0.74      0.74       494

# %%
#SVC
svc = SVC()
svc.fit(X_train,y_train)
svc_predictions = svc.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, svc_predictions))
print(classification_report(y_test, svc_predictions))
# Out:
# Accuracy:  0.6194331983805668
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.58       241
#            1       0.61      0.69      0.65       253
#
#     accuracy                           0.62       494
#    macro avg       0.62      0.62      0.62       494
# weighted avg       0.62      0.62      0.62       494

# %%
# DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train,y_train)
dtc_predictions = dtc.predict(X_test)
print("Accuracy: ", accuracy_score(y_test, dtc_predictions))
print(classification_report(y_test, dtc_predictions))
# Out:
# Accuracy:  0.9210526315789473
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91       241
#            1       0.88      0.98      0.93       253
#
#     accuracy                           0.92       494
#    macro avg       0.93      0.92      0.92       494
# weighted avg       0.93      0.92      0.92       494

# %% [markdown]
# Random Forest classifier being a good model as the accuracy score is of 96% and DecisionTreeClassifier can also be a good model of accuracy score of 92%
